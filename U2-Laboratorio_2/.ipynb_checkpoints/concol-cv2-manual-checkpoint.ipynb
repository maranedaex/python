# %% [markdown]
# # Concolucion from CV2

# %% [markdown]
# #  Convolucion Manual

# %% [markdown]
# Convolución
# Para cada píxel en la imagen de entrada, inspeccionaremos su vecino. Un núcleo 3x3  se asoma así
# en cada vecino de un píxel específico (hay vecinos de 8 píxeles) mientras que un núcleo de 5x5
# mira a dos píxeles en todas las direcciones (es decir, 24 píxeles vecinos).

# %%
import cv2
import numpy as np
import pandas as pd 


# carga la imagen en escala de 0..1
image = cv2.imread('lena512.bmp', cv2.IMREAD_GRAYSCALE).astype(float) / 255.0

# %%
# Un núcleo 3x3 de suavisado y que promedia todos los vecinos (suma todos, opcionalmente divide por conteo).
kernel_1 = (np.array([[1, 1, 1],
                    [1, 1, 1],
                    [1, 1, 1]]))

# detector de borde vertical
kernel = np.array([[1,  1,  1],
                   [0,  0,  0],
                   [-1, -1, -1]])


# los píxeles deben estar en el rango 0..1, por lo que dividimos por la suma de todos los núcleos
kernel_sum = kernel.sum()
if kernel_sum == 0: kernel_sum = 1
print('Procesando [detector de borde vertical 3x3] ', str(kernel_sum))
# busca las dimensiones para la iteración sobre los píxeles
i_width, i_height = image.shape[0], image.shape[1]
k_width, k_height = kernel.shape[0], kernel.shape[1]

# preparar la matriz de salida
filtered_1 = np.zeros_like(image)

for y in range(i_height):
    for x in range(i_width):
        weighted_pixel_sum = 0

        for ky in range(-(k_height // 2), k_height - 1):
            for kx in range(-(k_width // 2), k_width - 1):
                pixel = 0
                pixel_y = y - ky
                pixel_x = x - kx
                if (pixel_y >= 0) and (pixel_y < i_height) and (pixel_x >= 0) and (pixel_x < i_width):
                    pixel = image[pixel_y, pixel_x]
                weight = kernel[ky + (k_height // 2)-1, kx + (k_width // 2)-1]
                weighted_pixel_sum += pixel * weight
        filtered_1[y, x] = weighted_pixel_sum / kernel_sum
    
cv2.imshow('Salida file_borde_vertical_3x3', filtered_1)
pd.DataFrame(filtered_1).to_csv("file_borde_vertical_3x3.csv")
# Out:
# Procesando [detector de borde vertical 3x3]  1

# %%
# detector de borde horizontal
kernel = np.array([[1, 0, -1],
                   [1, 0, -1],
                   [1, 0, -1]])


# los píxeles deben estar en el rango 0..1, por lo que dividimos por la suma de todos los núcleos
kernel_sum = kernel.sum()
if kernel_sum == 0: kernel_sum = 1
print('Procesando [detector de borde horizontal 3x3] ', str(kernel_sum))
# busca las dimensiones para la iteración sobre los píxeles
i_width, i_height = image.shape[0], image.shape[1]
k_width, k_height = kernel.shape[0], kernel.shape[1]

# preparar la matriz de salida
filtered_2 = np.zeros_like(image)

for y in range(i_height):
    for x in range(i_width):
        weighted_pixel_sum = 0

        for ky in range(-(k_height // 2), k_height - 1):
            for kx in range(-(k_width // 2), k_width - 1):
                pixel = 0
                pixel_y = y - ky
                pixel_x = x - kx
                if (pixel_y >= 0) and (pixel_y < i_height) and (pixel_x >= 0) and (pixel_x < i_width):
                    pixel = image[pixel_y, pixel_x]
                weight = kernel[ky + (k_height // 2)-1, kx + (k_width // 2)-1]
                weighted_pixel_sum += pixel * weight
        filtered_2[y, x] = weighted_pixel_sum / kernel_sum
    
cv2.imshow('Salida detector de borde horizontal 3x3', filtered_2)
pd.DataFrame(filtered_2).to_csv("file_borde_horizontal_3x3.csv")
# Out:
# Procesando [detector de borde horizontal 3x3]  1

# %%
# filtro  5x5 de suavizado gaussiano
kernel = (np.array([[1, 4, 6, 4, 1],
                [4, 16, 24, 16, 4],
                [6, 24, 36, 24, 6],
                [4, 16, 24, 16, 4],
                [1, 4, 6, 4, 1]])) /256.0

# los píxeles deben estar en el rango 0..1, por lo que dividimos por la suma de todos los núcleos
kernel_sum = kernel.sum()
if kernel_sum == 0: kernel_sum = 1
print('Procesando [detector de suavizado gaussiano] ', str(kernel_sum))
# busca las dimensiones para la iteración sobre los píxeles
i_width, i_height = image.shape[0], image.shape[1]
k_width, k_height = kernel.shape[0], kernel.shape[1]

# preparar la matriz de salida
filtered_3 = np.zeros_like(image)

for y in range(i_height):
    for x in range(i_width):
        weighted_pixel_sum = 0

        for ky in range(-(k_height // 2), k_height - 1):
            for kx in range(-(k_width // 2), k_width - 1):
                pixel = 0
                pixel_y = y - ky
                pixel_x = x - kx
                if (pixel_y >= 0) and (pixel_y < i_height) and (pixel_x >= 0) and (pixel_x < i_width):
                    pixel = image[pixel_y, pixel_x]
                weight = kernel[ky + (k_height // 2)-1, kx + (k_width // 2)-1]
                weighted_pixel_sum += pixel * weight
        filtered_3[y, x] = weighted_pixel_sum / kernel_sum
    
cv2.imshow('Salida detector de suavizado gaussiano', filtered_3)
pd.DataFrame(filtered_3).to_csv("file_suavizado_gaussiano.csv")
# Out:
# Procesando [detector de suavizado gaussiano]  1.0

# %%
# filtro 5x5 detector de bordes,
kernel = (np.array([[1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1]]))

# los píxeles deben estar en el rango 0..1, por lo que dividimos por la suma de todos los núcleos
kernel_sum = kernel.sum()
if kernel_sum == 0: kernel_sum = 1
print('Procesando [detector de detector de bordes 5x5] ', str(kernel_sum))
# busca las dimensiones para la iteración sobre los píxeles
i_width, i_height = image.shape[0], image.shape[1]
k_width, k_height = kernel.shape[0], kernel.shape[1]

# preparar la matriz de salida
filtered_4 = np.zeros_like(image)

for y in range(i_height):
    for x in range(i_width):
        weighted_pixel_sum = 0

        for ky in range(-(k_height // 2), k_height - 1):
            for kx in range(-(k_width // 2), k_width - 1):
                pixel = 0
                pixel_y = y - ky
                pixel_x = x - kx
                if (pixel_y >= 0) and (pixel_y < i_height) and (pixel_x >= 0) and (pixel_x < i_width):
                    pixel = image[pixel_y, pixel_x]
                weight = kernel[ky + (k_height // 2)-1, kx + (k_width // 2)-1]
                weighted_pixel_sum += pixel * weight
        filtered_4[y, x] = weighted_pixel_sum / kernel_sum
    
cv2.imshow('Salida detector de bordes 5x5', filtered_4)
pd.DataFrame(filtered_4).to_csv("file_detector_bordes_5x5.csv")
# Out:
# Procesando [detector de detector de bordes 5x5]  1

# %% [markdown]
# # Libera recursos de memoria cv2

# %%
# wait and quit
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Calcular la transformada de Fourier en 2D para la imagen original

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('lena512.bmp',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Calcular FFT de imagen filtrada (detector bordes horizontal)

# %%
# detector de bordes Horizontal
kernel = np.array([[1, 0, -1],
                   [1, 0, -1],
                   [1, 0, -1]])

filtered = cv2.filter2D(src=img, kernel=kernel, ddepth=-1)

f = np.fft.fft2(filtered)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(filtered, cmap = 'gray')
plt.title('Image Filtrada bordes Horizontal'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Calcular FFT de imagen filtrada (detector bordes vertical)

# %%
# detector de borde vertical
kernel = np.array([[1,  1,  1],
                   [0,  0,  0],
                   [-1, -1, -1]])

filtered = cv2.filter2D(src=img, kernel=kernel, ddepth=-1)

f = np.fft.fft2(filtered)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(filtered, cmap = 'gray')
plt.title('Image Filtrada bordes Horizontal'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Calcular FFT de imagen filtrada (5x5 de suavizado gaussiano)

# %%
# filtro  5x5 de suavizado gaussiano
kernel = (np.array([[1, 4, 6, 4, 1],
                [4, 16, 24, 16, 4],
                [6, 24, 36, 24, 6],
                [4, 16, 24, 16, 4],
                [1, 4, 6, 4, 1]])) /256.0

filtered = cv2.filter2D(src=img, kernel=kernel, ddepth=-1)

f = np.fft.fft2(filtered)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(filtered, cmap = 'gray')
plt.title('Image Filtrada bordes Horizontal'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Calcular FFT de imagen filtrada (5x5 detector de bordes)

# %%
# filtro 5x5 detector de bordes,
kernel = (np.array([[1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1],
                [1, 2, 0, -2, -1]]))

filtered = cv2.filter2D(src=img, kernel=kernel, ddepth=-1)

f = np.fft.fft2(filtered)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(filtered, cmap = 'gray')
plt.title('Image Filtrada bordes Horizontal'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# close y salir
cv2.waitKey(0)
cv2.destroyAllWindows()
